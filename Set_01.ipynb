# %% [markdown]
# The first program

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# ## Lists, sets and tuples

# %%
a = [1, 1, 2, 3, 5, 2, 6, 7, 7, 5]  #This is a list
b = {1, 1, 2, 3, 5, 2, 6, 7, 7, 5}  #This is a set
c = (1, 1, 2, 3, 5, 2, 6, 7, 7, 5)  #This is a tuple

# %% [markdown]
# Now print each one to see what's the difference between them.

# %%
print('a =', a)
print('b =', b)
print('c=', c)
# Out:
# a = [1, 1, 2, 3, 5, 2, 6, 7, 7, 5]
# b = {1, 2, 3, 5, 6, 7}
# c= (1, 1, 2, 3, 5, 2, 6, 7, 7, 5)

# %% [markdown]
# As you see, sets behave in the way that we expect from math, they only keep one instance of each member and disregard the rest. We can put all kinds of objects in a set, list or tuple.

# %%
d = ['Salam', 'Sib', 35.43, 12, b, 'x'+'y', 44]
print(d)
# Out:
# ['Salam', 'Sib', 35.43, 12, {1, 2, 3, 5, 6, 7}, 'xy', 44]

# %% [markdown]
#  Also try this for a set and a tuple and print the results.

# %%
e = {'Salam', 'Sib', 35.43, 12, c, 'x'+'y', 44}
d = ('Salam', 'Sib', 35.43, 12, c, 'x'+'y', 44)
print(e)
print(d)
# Out:
# {'xy', 'Sib', 35.43, 'Salam', 12, 44, (1, 1, 2, 3, 5, 2, 6, 7, 7, 5)}
# ('Salam', 'Sib', 35.43, 12, (1, 1, 2, 3, 5, 2, 6, 7, 7, 5), 'xy', 44)

# %% [markdown]
# Now let's see the differense between lists and tuples.

# %%
a.append([32, 54, 'Adas'])
print(a)
# Out:
# [1, 1, 2, 3, 5, 2, 6, 7, 7, 5, [32, 54, 'Adas']]

# %%
a.remove(7)
print(a)
# Out:
# [1, 1, 2, 3, 5, 2, 6, 7, 5, [32, 54, 'Adas']]

# %%
c.count(1)
# Out:
# 2

# %% [markdown]
# In general, tuples are faster than lists, but lists have many more atributes and options. To see which options either have, type the variable with dot (".") after it and wait to see the options. To see what each option will do, you can type a question mark ("?") before it and run the cell. Now run the cell below and see what happens.

# %%
# ?a.sort

# %% [markdown]
# Now using the options introduced above, try to make the list "a" to look like the tuple "b".

# %%
a.remove([32, 54, 'Adas'])
a.insert(8,7)
print('a=',a)
print('c=',c)
# Out:
# a= [1, 1, 2, 3, 5, 2, 6, 7, 7, 5]
# c= (1, 1, 2, 3, 5, 2, 6, 7, 7, 5)

# %% [markdown]
# # Loops and indexing

# %% [markdown]
# You can access the members of a list (or tuple) with indexing them as follows:

# %%
print('The first member of tuple "c" is:', c[0])
print('The third member of tuple "c" is:', c[2])
print('The last member of tuple "c" is:', c[-1])
print('The third to last member of tuple "c" is:', c[-3])
# Out:
# The first member of tuple "c" is: 1
# The third member of tuple "c" is: 2
# The last member of tuple "c" is: 5
# The third to last member of tuple "c" is: 7

# %% [markdown]
# ## For loops
# Let's see two examples

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for cc in c:
    print(cc**2)
# Out:
# 1
# 1
# 4
# 9
# 25
# 4
# 36
# 49
# 49
# 25

# %% [markdown]
# Now write a code to print the members of "a" list defiend as below in reverse order.

# %%
a = [1, 1, 2, 3, 5, 2, 6, 7, 7, 5, [32, 54, 'Adas']]

for i in range(5):
    h = a[i]
    a[i]=a[-i-1]
    a[-i-1]=h

print(a)
# Out:
# [[32, 54, 'Adas'], 5, 7, 7, 6, 2, 5, 3, 2, 1, 1]

# %% [markdown]
# ## While loops
# It runs while the argument is true. Compelete the code below to get the desired result.

# %%
a = [1, 1, 2, 3, 5, 2, 6, 7, 7, 5, [32, 54, 'Adas']]
i = 10
while i >= 0:
    print(a[i])
    i-=1
# Out:
# [32, 54, 'Adas']
# 5
# 7
# 7
# 6
# 2
# 5
# 3
# 2
# 1
# 1

# %% [markdown]
# # if, else, elif

# %%
x = 5

if x > 5:
  print('Yay!!')

elif x < 5:
  print("Nay :(")

else:
  print("Meh..")
# Out:
# Meh..

# %% [markdown]
# Now using the example provided above and your knowledge of loops, write a piece of code to print the apropriate messages for each member of the tuple "c".

# %%
c = (1, 1, 2, 3, 5, 2, 6, 7, 7, 5)
for i in range(10):
    if c[i] > 5:
        print("c [",i,"] = ",c[i]," => Yay!!")
    elif c[i] < 5:
        print("c [",i,"] = ",c[i]," => Nay :(")
    else:
        print("c [",i,"] = ",c[i]," => Meh..")
# Out:
# c [ 0 ] =  1  => Nay :(
# c [ 1 ] =  1  => Nay :(
# c [ 2 ] =  2  => Nay :(
# c [ 3 ] =  3  => Nay :(
# c [ 4 ] =  5  => Meh..
# c [ 5 ] =  2  => Nay :(
# c [ 6 ] =  6  => Yay!!
# c [ 7 ] =  7  => Yay!!
# c [ 8 ] =  7  => Yay!!
# c [ 9 ] =  5  => Meh..

# %% [markdown]
# # Libraries

# %% [markdown]
# Libraries are collections of many pre-written programs that enable us to write code much more easily. In other words, it's like importing a library expands available python commands.
#
# There are three ways to import commands from library.
#
# ### 1) Import the whole library

# %%
import time

# %% [markdown]
# Now we can use the commands inside "time" by using the familirar "dot" operator.

# %%
print(time.localtime())
# Out:
# time.struct_time(tm_year=2022, tm_mon=2, tm_mday=23, tm_hour=23, tm_min=45, tm_sec=29, tm_wday=2, tm_yday=54, tm_isdst=0)

# %% [markdown]
# ### 2) Import certain functions (or classes) from a library

# %%
from math import pi, sin

# %%
print(sin(pi/2))
# Out:
# 1.0

# %% [markdown]
# ### 3) Import the whole library or certain commands with a different name

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# We are going to learn how to use these two libraries in the next section.
#
# ## Installing new libraries in Google colab
#
# To do this you need the command "pip".

# %%
# !pip install sxs
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sxs in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (2021.0.5)
# Requirement already satisfied: pandas<2.0.0,>=1.1.2 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (1.4.1)
# Requirement already satisfied: inflection<0.6.0,>=0.5.1 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (0.5.1)
# Requirement already satisfied: numpy<2.0,>=1.15 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (1.20.1)
# Requirement already satisfied: numba>=0.50 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (0.55.1)
# Requirement already satisfied: black>=20.8b1 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (22.1.0)
# Requirement already satisfied: scipy<2.0,>=1.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (1.6.1)
# Requirement already satisfied: tqdm<4.61.2,>=4.48.2 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (4.61.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.10 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (1.26.8)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (2.27.1)
# Requirement already satisfied: pytz<2021.0,>=2020.1 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (2020.5)
# Requirement already satisfied: pytest-forked<2.0.0,>=1.3.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (1.4.0)
# Requirement already satisfied: pylatexenc<3.0,>=2.7 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (2.10)
# Requirement already satisfied: spherical<2.0,>=1.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (1.0.11)
# Requirement already satisfied: feedparser<7.0.0,>=6.0.1 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (6.0.8)
# Requirement already satisfied: h5py<4,>=3 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (3.6.0)
# Requirement already satisfied: quaternionic<2.0,>=1.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from sxs) (1.0.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from black>=20.8b1->sxs) (2.5.1)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from black>=20.8b1->sxs) (0.9.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from black>=20.8b1->sxs) (8.0.4)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from black>=20.8b1->sxs) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from black>=20.8b1->sxs) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from black>=20.8b1->sxs) (4.1.1)
# Requirement already satisfied: sgmllib3k in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from feedparser<7.0.0,>=6.0.1->sxs) (1.0.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from numba>=0.50->sxs) (0.38.0)
# Requirement already satisfied: setuptools in c:\program files\python38\lib\site-packages (from numba>=0.50->sxs) (47.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from pandas<2.0.0,>=1.1.2->sxs) (2.8.1)
# Requirement already satisfied: pytest>=3.10 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from pytest-forked<2.0.0,>=1.3.0->sxs) (7.0.1)
# Requirement already satisfied: py in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from pytest-forked<2.0.0,>=1.3.0->sxs) (1.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.24.0->sxs) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.24.0->sxs) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.24.0->sxs) (2.0.12)
# Requirement already satisfied: colorama in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from click>=8.0.0->black>=20.8b1->sxs) (0.4.4)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from pytest>=3.10->pytest-forked<2.0.0,>=1.3.0->sxs) (1.0.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from pytest>=3.10->pytest-forked<2.0.0,>=1.3.0->sxs) (1.4.0)
# Requirement already satisfied: iniconfig in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from pytest>=3.10->pytest-forked<2.0.0,>=1.3.0->sxs) (1.1.1)
# Requirement already satisfied: packaging in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from pytest>=3.10->pytest-forked<2.0.0,>=1.3.0->sxs) (21.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from pytest>=3.10->pytest-forked<2.0.0,>=1.3.0->sxs) (21.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.1.2->sxs) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\g.v shop\appdata\roaming\python\python38\site-packages (from packaging->pytest>=3.10->pytest-forked<2.0.0,>=1.3.0->sxs) (2.4.7)

# %% [markdown]
# 'sxs' is a library for simulation gravitational waves. We won't be needing this in this course.

# %% [markdown]
# # Numpy
#
# Numpy is the standard library for doing numerical calculations for scientific purposes in python. It provides a new kind of data sructure called "numpy array". While it is more restrictive that normal python lists, it enables us to do vector operations which is (for the most part) much faster. It also provides a wide range of mathematical and statistical operations for the arrys. Let's import numpy and see some examples.

# %%
import numpy as np

# %%
a = np.array([1, 1, 2, 3, 5, 8, 13, 21, 34])
print(a)
# Out:
# [ 1  1  2  3  5  8 13 21 34]

# %%
print(np.sum(a))
# Out:
# 88

# %%
a.max()
# Out:
# 34

# %%
a.mean()
# Out:
# 9.777777777777779

# %% [markdown]
# And for some vectorized operations:

# %%
print(3 * a)
# Out:
# [  3   3   6   9  15  24  39  63 102]

# %%
b = np.ones(len(a))
print(b)
# Out:
# [1. 1. 1. 1. 1. 1. 1. 1. 1.]

# %%
print(a + b)
# Out:
# [ 2.  2.  3.  4.  6.  9. 14. 22. 35.]

# %%
for i in range(len(a)):
  print(a[i] + b[i])
# Out:
# 2.0
# 2.0
# 3.0
# 4.0
# 6.0
# 9.0
# 14.0
# 22.0
# 35.0

# %% [markdown]
# As you might have noticed, array "a" shows the first 9 Fibonacci numbers. Now write a piece of code to turn b into a.

# %%
b = np.ones(len(a))
for i in range(len(b)-2):
    b[i+2] = b[i+1] + b[i]

print(b)
# Out:
# [ 1.  1.  2.  3.  5.  8. 13. 21. 34.]

# %% [markdown]
# As another exercise, make a numpy array of size 100 using "linspace" between 0 and 2$\pi$, and calculate the sine of each member in a vectorized manner and put it in a new array.

# %%
from math import pi
x = np.linspace(0, 2*pi, num=100)
y = np.sin(x)
print(y)
# Out:
# [ 0.00000000e+00  6.34239197e-02  1.26592454e-01  1.89251244e-01
#   2.51147987e-01  3.12033446e-01  3.71662456e-01  4.29794912e-01
#   4.86196736e-01  5.40640817e-01  5.92907929e-01  6.42787610e-01
#   6.90079011e-01  7.34591709e-01  7.76146464e-01  8.14575952e-01
#   8.49725430e-01  8.81453363e-01  9.09631995e-01  9.34147860e-01
#   9.54902241e-01  9.71811568e-01  9.84807753e-01  9.93838464e-01
#   9.98867339e-01  9.99874128e-01  9.96854776e-01  9.89821442e-01
#   9.78802446e-01  9.63842159e-01  9.45000819e-01  9.22354294e-01
#   8.95993774e-01  8.66025404e-01  8.32569855e-01  7.95761841e-01
#   7.55749574e-01  7.12694171e-01  6.66769001e-01  6.18158986e-01
#   5.67059864e-01  5.13677392e-01  4.58226522e-01  4.00930535e-01
#   3.42020143e-01  2.81732557e-01  2.20310533e-01  1.58001396e-01
#   9.50560433e-02  3.17279335e-02 -3.17279335e-02 -9.50560433e-02
#  -1.58001396e-01 -2.20310533e-01 -2.81732557e-01 -3.42020143e-01
#  -4.00930535e-01 -4.58226522e-01 -5.13677392e-01 -5.67059864e-01
#  -6.18158986e-01 -6.66769001e-01 -7.12694171e-01 -7.55749574e-01
#  -7.95761841e-01 -8.32569855e-01 -8.66025404e-01 -8.95993774e-01
#  -9.22354294e-01 -9.45000819e-01 -9.63842159e-01 -9.78802446e-01
#  -9.89821442e-01 -9.96854776e-01 -9.99874128e-01 -9.98867339e-01
#  -9.93838464e-01 -9.84807753e-01 -9.71811568e-01 -9.54902241e-01
#  -9.34147860e-01 -9.09631995e-01 -8.81453363e-01 -8.49725430e-01
#  -8.14575952e-01 -7.76146464e-01 -7.34591709e-01 -6.90079011e-01
#  -6.42787610e-01 -5.92907929e-01 -5.40640817e-01 -4.86196736e-01
#  -4.29794912e-01 -3.71662456e-01 -3.12033446e-01 -2.51147987e-01
#  -1.89251244e-01 -1.26592454e-01 -6.34239197e-02 -2.44929360e-16]

# %% [markdown]
# # Matplotlib
#
# Matplotlib is a library used for simple plotting. It is basically the python version of Matlab plot and is sufficient for most scientific purposes. There are also more advanced plotting libraries like "Seaborn" and "Plotly".

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Now lt's plot the sine function we made above

# %%
# %matplotlib notebook
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.legend('Sin(x)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# This is the basic plotting function. you can add labels, legends, change fonts, etc..
#
# As an exercise, add labels for the x and y axes to the plot above, and also label the line.

# %% [markdown]
# # Reading and writing files using numpy

# %% [markdown]
# For reading and writing text files with numpy, we can use "readtxt" and "savetxt" commands. Let's see some examples.

# %%
data_to_save = np.column_stack((x, y))
np.savetxt('sine_function', data_to_save)

# %% [markdown]
# Now for exercise, try to save the data with a header.

# %%
np.savetxt('sine_function_with_header', data_to_save, header="x       y=Sin(x)", comments='')

# %%
data_to_read = np.loadtxt('sine_function')

# %% [markdown]
# To see whether it's the same data or not, we can plot it.

# %%
plt.plot(data_to_read[:,0], data_to_read[:,1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now as an exercise, try to read the file into twe seperate variables. (insted of having just "data_to_read" read it into "x" and "y", each corresponding to an axis.

# %%
np.savetxt('X', x)
np.savetxt('Y', y)
X = np.loadtxt('X')
Y = np.loadtxt('Y')
plt.plot(X[:], Y[:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Functions

# %% [markdown]
# Functions in python, are defined using the command "def". If a variable is defined inside of a function, when we run that function, the variable is local and it's value is lost when we retrun the function. On the other hand if we do not define a variable tha we use in a function, function tries to read a globally defined variable with the same name. If it is not defined before running the function, we will see an error.
#
# As an example, let's define a function that returns the sum of two input variables.

# %%
def my_sum_function(x, y):
  return x + y

# %%
my_sum_function(10, 12)
# Out:
# 22

# %% [markdown]
# Now try to write a function that reads a number N and returns the Nth Fibonacci number.

# %%
def Fibonacci(N):
    F = np.ones(N)
    if N < 2:
        F[0] = 1
    elif N == 2:
        F[1] = 1
    else:
        F[0] = 1
        F[1] = 1
        for i in range(N-2):
            F[i+2] = F[i+1] + F[i]
    
    return F[N-1]

# %%
Fibonacci(8)
# Out:
# 21.0
